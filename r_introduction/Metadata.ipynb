# %%
some_list = c(40, 44, 38, 48, 35, 42)

# %%
comment(some_list) = c('Heights of 3rd Grade Students in Inches')

# %%
comment(some_list)
# Out:
# [1] "Heights of 3rd Grade Students in Inches"

# %%
some_matrix <- matrix(1:20, 4, 5)
some_matrix
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 1    5     9   13   17
# [2,] 2    6    10   14   18
# [3,] 3    7    11   15   19
# [4,] 4    8    12   16   20

# %%
comment(some_matrix) = c(info='Important Matrix Containing Secret Information', date='December 2020')
comment(some_matrix)
# Out:
#                                             info
# "Important Matrix Containing Secret Information"
#                                             date
#                                  "December 2020"

# %%
some_matrix
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 1    5     9   13   17
# [2,] 2    6    10   14   18
# [3,] 3    7    11   15   19
# [4,] 4    8    12   16   20

# %%
install.packages(c('NLP','tm'))
# Out:
# also installing the dependency ‘slam’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(NLP)
library(tm)

# %%
data('crude')

# %%
crude
# Out:
# <<VCorpus>>
# Metadata:  corpus specific: 0, document level (indexed): 0
# Content:  documents: 20

# %%
meta(crude, tag='dataset', type='corpus') <- 'Crude Oil'

# %%
meta(crude, type='corpus')
# Out:
# $dataset
# [1] "Crude Oil"
#
# attr(,"class")
# [1] "CorpusMeta"

# %%
meta(crude,  tag='dataset')
# Out:
# [1] "Crude Oil"

# %%
meta(crude, tag='labels') <- 'Oil News'

# %%
meta(crude, type='indexed')
# Out:
#    labels
# 1  Oil News
# 2  Oil News
# 3  Oil News
# 4  Oil News
# 5  Oil News
# 6  Oil News
# 7  Oil News
# 8  Oil News
# 9  Oil News
# 10 Oil News
# 11 Oil News
# 12 Oil News
# 13 Oil News
# 14 Oil News
# 15 Oil News
# 16 Oil News
# 17 Oil News
# 18 Oil News
# 19 Oil News
# 20 Oil News

# %%
sample <- sapply(crude, function(x) {x$content})

# %%
sample
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
strwrap(crude[[1]])
# Out:
# [1] "Diamond Shamrock Corp said that effective today it had cut its contract"
# [2] "prices for crude oil by 1.50 dlrs a barrel.  The reduction brings its"
# [3] "posted price for West Texas Intermediate to 16.00 dlrs a barrel, the"
# [4] "copany said.  \"The price reduction today was made in the light of"
# [5] "falling oil product prices and a weak crude oil market,\" a company"
# [6] "spokeswoman said.  Diamond is the latest in a line of U.S. oil"
# [7] "companies that have cut its contract, or posted, prices over the last"
# [8] "two days citing weak oil markets.  Reuter"

# %%
crude([1])
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:7: unexpected '['
# 1: crude([
#           ^
# Traceback:

# %%
meta(crude[[1]])
# Out:
#   author       : character(0)
#   datetimestamp: 1987-02-26 17:00:56
#   description  :
#   heading      : DIAMOND SHAMROCK (DIA) CUTS CRUDE PRICES
#   id           : 127
#   language     : en
#   origin       : Reuters-21578 XML
#   topics       : YES
#   lewissplit   : TRAIN
#   cgisplit     : TRAINING-SET
#   oldid        : 5670
#   places       : usa
#   people       : character(0)
#   orgs         : character(0)
#   exchanges    : character(0)

# %%
crude[[1]]
# Out:
# <<PlainTextDocument>>
# Metadata:  15
# Content:  chars: 527

# %%
crude[1]
# Out:
# <<VCorpus>>
# Metadata:  corpus specific: 1, document level (indexed): 1
# Content:  documents: 1
